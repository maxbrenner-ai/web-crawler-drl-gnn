# %%
# %matplotlib inline
import networkx as nx
from utils import *
import matplotlib.pyplot as plt

# %%
# dir = 'data/animals-D3-20K-nodes54-avgedges3.1-totaledges254-max10-minout1-minin1/'
dir = 'data/animals-D3-20K-nodes41-avgedges3.7-totaledges254-max10-minout2-minin2/'

# %%
G_whole, pages, node_feats, edges = load_data_make_graph_nervenet(get_data_path(dir, 0))

# %%
nx.draw_kamada_kawai(G_whole, with_labels=True)
plt.show()
