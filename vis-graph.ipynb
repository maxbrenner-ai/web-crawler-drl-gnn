# %%
# %matplotlib inline
import networkx as nx
from utils import *
import matplotlib.pyplot as plt

# %%
# dir = 'data/animals-D3-20K-nodes54-avgedges3.1-totaledges254-max10-minout1-minin1/'
dir = 'data/animals-D4-60K-sorted-nodes41-avgedges5.2-totaledges215-max10-minout3-minin3/features_soup.pkl'

# %%
G_whole, pages, node_feats, edge_feats, edges = load_data_make_graph(dir)

# %%
nx.draw_kamada_kawai(G_whole, with_labels=True)
plt.show()

# %%
nx.draw_spectral(G_whole, with_labels=True)
plt.show()
